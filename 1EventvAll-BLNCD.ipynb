# %%
import sys
import glob
import numpy
from random import shuffle

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.pipeline import Pipeline

from sklearn.linear_model import SGDClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import PassiveAggressiveClassifier

from sklearn.neighbors import KNeighborsClassifier

from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC

from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %%
def sz(a): # str/eval
    return {
        'text': a.text,
        'title': a.title,
        'url': a.url,
        'keywords': a.keywords,
        'tags': a.tags,
        'summary': a.summary,
        'date': int(a.publish_date.timestamp()) if a.publish_date != None else None,
        'raw' : a.html
    }

# %%
def objRead(f):
    return eval(open(f, 'r').read())

def objWrite(f, data):
    f = f.split('.')[0]
    open(f + '.lobj', 'w').write(str(data)) # light obj

# %%
for f in glob.iglob('**/*.lobj', recursive=True):
    print(f)
# Out:
# other.lobj
# disasters/shootings/sandyhook.lobj
# disasters/shootings/orlando.lobj
# disasters/shootings/lasvegas.lobj
# disasters/shootings/sanbernardino.lobj
# disasters/earthquakes/sumatra.lobj
# disasters/earthquakes/haiti.lobj
# disasters/earthquakes/sichuan.lobj
# disasters/earthquakes/kashmir.lobj
# disasters/wildfires/thomas.lobj
# disasters/wildfires/attica.lobj
# disasters/wildfires/mountcarmel.lobj
# disasters/wildfires/nevada.lobj
# disasters/hurricanes/jeanne.lobj
# disasters/hurricanes/stan.lobj
# disasters/hurricanes/maria.lobj
# disasters/hurricanes/katrina.lobj

# %%
data = [
    { 'articles': objRead('disasters/shootings/lasvegas.lobj'), 'label': 'lasvegas' },
    { 'articles': objRead('disasters/shootings/orlando.lobj'), 'label': 'orlando' },
    { 'articles': objRead('disasters/shootings/sandyhook.lobj'), 'label': 'sandyhook' },
    { 'articles': objRead('disasters/shootings/sanbernardino.lobj'), 'label': 'sanbernardino' },
    { 'articles': objRead('disasters/earthquakes/kashmir.lobj'), 'label': 'kashmir' },
    { 'articles': objRead('disasters/earthquakes/haiti.lobj'), 'label': 'haiti' },
    { 'articles': objRead('disasters/earthquakes/sumatra.lobj'), 'label': 'sumatra' },
    { 'articles': objRead('disasters/earthquakes/sichuan.lobj'), 'label': 'sichuan' },
#     { 'articles': objRead('disasters/wildfires/mountcarmel.lobj'), 'label': 'mountcarmel' }, # only 19 articles
    { 'articles': objRead('disasters/wildfires/attica.lobj'), 'label': 'attica' },
    { 'articles': objRead('disasters/wildfires/nevada.lobj'), 'label': 'nevada' },
    { 'articles': objRead('disasters/wildfires/thomas.lobj'), 'label': 'thomas' },
    { 'articles': objRead('disasters/hurricanes/maria.lobj'), 'label': 'maria' },
    { 'articles': objRead('disasters/hurricanes/katrina.lobj'), 'label': 'katrina' }
#     { 'articles': objRead('disasters/hurricanes/jeanne.lobj'), 'label': 'jeanne' }, # only 35 articles
#     { 'articles': objRead('disasters/hurricanes/stan.lobj'), 'label': 'stan'} # only 29 articles
]

labels = [x['label'] for x in data]

# %%
classifiers = [
    SGDClassifier(loss='hinge',
                  penalty='elasticnet',
                  alpha=1e-3,
                  max_iter=1000,
                  tol=None),
    MultinomialNB(),
    PassiveAggressiveClassifier(max_iter=200),
    KNeighborsClassifier(n_neighbors=len(data)),
    RandomForestClassifier(n_estimators=200,
                           max_depth=3),
    LogisticRegression(),
    LinearSVC()
]

# %%
for label in labels:    
    train_data, test_data = [], []
    train_label, test_label = numpy.array([]), numpy.array([])

    TRAIN_SIZE = 40

    for cat in data:
        l = int(cat['label'] != label)
        shuffle(cat['articles'])
        
        s = 0
        for x in cat['articles'][:TRAIN_SIZE]:
            if 'washingtonpost' in x['url']:
                continue
                
            if l:
                if s > 1.25 * TRAIN_SIZE / len(data):
                    break
                s += 1
                
            train_data.append(x['text'])
            train_label = numpy.append(train_label, l)
            
        s = 0
        for x in cat['articles'][TRAIN_SIZE:]:
            if 'washingtonpost' in x['url']:
                continue
                
            if l:
                if s > 1.25 * TRAIN_SIZE / len(data):
                    break
                s += 1
                
            test_data.append(x['text'])
            test_label = numpy.append(test_label, l)
            
    test_data += train_data
    test_label = numpy.append(test_label, train_label)
    
    for c in classifiers:
        clf = Pipeline([('vect', CountVectorizer()),
                        ('tfidf', TfidfTransformer()),
                        ('clf', c),
        ])
        clf.fit(train_data, train_label)
                
        pred_label = clf.predict(test_data)
        print(type(c).__name__, accuracy_score(test_label, pred_label))
        print(classification_report(test_label, pred_label, target_names = [label, 'others']))
        print(confusion_matrix(test_label, pred_label))
# Out:
# SGDClassifier 0.9788359788359788
#              precision    recall  f1-score   support
#
#    lasvegas       0.99      0.97      0.98        93
#      others       0.97      0.99      0.98        96
#
# avg / total       0.98      0.98      0.98       189
#
# [[90  3]
#  [ 1 95]]
# MultinomialNB 0.9735449735449735
#              precision    recall  f1-score   support
#
#    lasvegas       0.98      0.97      0.97        93
#      others       0.97      0.98      0.97        96
#
# avg / total       0.97      0.97      0.97       189
#
# [[90  3]
#  [ 2 94]]
# PassiveAggressiveClassifier 0.9735449735449735
#              precision    recall  f1-score   support
#
#    lasvegas       0.97      0.98      0.97        93
#      others       0.98      0.97      0.97        96
#
# avg / total       0.97      0.97      0.97       189
#
# [[91  2]
#  [ 3 93]]
# KNeighborsClassifier 0.7301587301587301
#              precision    recall  f1-score   support
#
#    lasvegas       0.65      1.00      0.78        93
#      others       1.00      0.47      0.64        96
#
# avg / total       0.83      0.73      0.71       189
#
# [[93  0]
#  [51 45]]
# RandomForestClassifier 0.8624338624338624
#              precision    recall  f1-score   support
#
#    lasvegas       1.00      0.72      0.84        93
#      others       0.79      1.00      0.88        96
#
# avg / total       0.89      0.86      0.86       189
#
# [[67 26]
#  [ 0 96]]
# LogisticRegression 0.9417989417989417
#              precision    recall  f1-score   support
#
#    lasvegas       0.99      0.89      0.94        93
#      others       0.90      0.99      0.95        96
#
# avg / total       0.95      0.94      0.94       189
#
# [[83 10]
#  [ 1 95]]
# LinearSVC 0.9788359788359788
#              precision    recall  f1-score   support
#
#    lasvegas       0.99      0.97      0.98        93
#      others       0.97      0.99      0.98        96
#
# avg / total       0.98      0.98      0.98       189
#
# [[90  3]
#  [ 1 95]]
# SGDClassifier 0.9518716577540107
#              precision    recall  f1-score   support
#
#     orlando       0.99      0.91      0.95        91
#      others       0.92      0.99      0.95        96
#
# avg / total       0.95      0.95      0.95       187
#
# [[83  8]
#  [ 1 95]]
# MultinomialNB 0.9411764705882353
#              precision    recall  f1-score   support
#
#     orlando       0.94      0.93      0.94        91
#      others       0.94      0.95      0.94        96
#
# avg / total       0.94      0.94      0.94       187
#
# [[85  6]
#  [ 5 91]]
# PassiveAggressiveClassifier 0.9572192513368984
#              precision    recall  f1-score   support
#
#     orlando       1.00      0.91      0.95        91
#      others       0.92      1.00      0.96        96
#
# avg / total       0.96      0.96      0.96       187
#
# [[83  8]
#  [ 0 96]]
# KNeighborsClassifier 0.8074866310160428
#              precision    recall  f1-score   support
#
#     orlando       0.74      0.95      0.83        91
#      others       0.93      0.68      0.78        96
#
# avg / total       0.83      0.81      0.80       187
#
# [[86  5]
#  [31 65]]
# RandomForestClassifier 0.9358288770053476
#              precision    recall  f1-score   support
#
#     orlando       1.00      0.87      0.93        91
#      others       0.89      1.00      0.94        96
#
# avg / total       0.94      0.94      0.94       187
#
# [[79 12]
#  [ 0 96]]
# LogisticRegression 0.9411764705882353
#              precision    recall  f1-score   support
#
#     orlando       1.00      0.88      0.94        91
#      others       0.90      1.00      0.95        96
#
# avg / total       0.95      0.94      0.94       187
#
# [[80 11]
#  [ 0 96]]
# LinearSVC 0.9518716577540107
#              precision    recall  f1-score   support
#
#     orlando       0.99      0.91      0.95        91
#      others       0.92      0.99      0.95        96
#
# avg / total       0.95      0.95      0.95       187
#
# [[83  8]
#  [ 1 95]]
# SGDClassifier 0.9738219895287958
#              precision    recall  f1-score   support
#
#   sandyhook       0.99      0.96      0.97        95
#      others       0.96      0.99      0.97        96
#
# avg / total       0.97      0.97      0.97       191
#
# [[91  4]
#  [ 1 95]]
# MultinomialNB 0.9319371727748691
#              precision    recall  f1-score   support
#
#   sandyhook       0.99      0.87      0.93        95
#      others       0.89      0.99      0.94        96
#
# avg / total       0.94      0.93      0.93       191
#
# [[83 12]
#  [ 1 95]]
# PassiveAggressiveClassifier 0.9738219895287958
#              precision    recall  f1-score   support
#
#   sandyhook       0.99      0.96      0.97        95
#      others       0.96      0.99      0.97        96
#
# avg / total       0.97      0.97      0.97       191
#
# [[91  4]
#  [ 1 95]]
# KNeighborsClassifier 0.93717277486911
#              precision    recall  f1-score   support
#
#   sandyhook       0.90      0.98      0.94        95
#      others       0.98      0.90      0.93        96
#
# avg / total       0.94      0.94      0.94       191
#
# [[93  2]
#  [10 86]]
# RandomForestClassifier 0.9109947643979057
#              precision    recall  f1-score   support
#
#   sandyhook       0.98      0.84      0.90        95
#      others       0.86      0.98      0.92        96
#
# avg / total       0.92      0.91      0.91       191
#
# [[80 15]
#  [ 2 94]]
# LogisticRegression 0.9319371727748691
#              precision    recall  f1-score   support
#
#   sandyhook       0.99      0.87      0.93        95
#      others       0.89      0.99      0.94        96
#
# avg / total       0.94      0.93      0.93       191
#
# [[83 12]
#  [ 1 95]]
# LinearSVC 0.9685863874345549
#              precision    recall  f1-score   support
#
#   sandyhook       0.99      0.95      0.97        95
#      others       0.95      0.99      0.97        96
#
# avg / total       0.97      0.97      0.97       191
#
# [[90  5]
#  [ 1 95]]
# SGDClassifier 0.9637305699481865
#                precision    recall  f1-score   support
#
# sanbernardino       0.96      0.97      0.96        97
#        others       0.97      0.96      0.96        96
#
#   avg / total       0.96      0.96      0.96       193
#
# [[94  3]
#  [ 4 92]]
# MultinomialNB 0.9585492227979274
#                precision    recall  f1-score   support
#
# sanbernardino       0.98      0.94      0.96        97
#        others       0.94      0.98      0.96        96
#
#   avg / total       0.96      0.96      0.96       193
#
# [[91  6]
#  [ 2 94]]
# PassiveAggressiveClassifier 0.9481865284974094
#                precision    recall  f1-score   support
#
# sanbernardino       1.00      0.90      0.95        97
#        others       0.91      1.00      0.95        96
#
#   avg / total       0.95      0.95      0.95       193
#
# [[87 10]
#  [ 0 96]]
# KNeighborsClassifier 0.844559585492228
#                precision    recall  f1-score   support
#
# sanbernardino       0.79      0.94      0.86        97
#        others       0.92      0.75      0.83        96
#
#   avg / total       0.86      0.84      0.84       193
#
# [[91  6]
#  [24 72]]
# RandomForestClassifier 0.917098445595855
#                precision    recall  f1-score   support
#
# sanbernardino       0.99      0.85      0.91        97
#        others       0.86      0.99      0.92        96
#
#   avg / total       0.93      0.92      0.92       193
#
# [[82 15]
#  [ 1 95]]
# LogisticRegression 0.9326424870466321
#                precision    recall  f1-score   support
#
# sanbernardino       0.98      0.89      0.93        97
#        others       0.90      0.98      0.94        96
#
#   avg / total       0.94      0.93      0.93       193
#
# [[86 11]
#  [ 2 94]]
# LinearSVC 0.9585492227979274
#                precision    recall  f1-score   support
#
# sanbernardino       0.98      0.94      0.96        97
#        others       0.94      0.98      0.96        96
#
#   avg / total       0.96      0.96      0.96       193
#
# [[91  6]
#  [ 2 94]]
# SGDClassifier 1.0
#              precision    recall  f1-score   support
#
#     kashmir       1.00      1.00      1.00        58
#      others       1.00      1.00      1.00        96
#
# avg / total       1.00      1.00      1.00       154
#
# [[58  0]
#  [ 0 96]]
# MultinomialNB 0.987012987012987
#              precision    recall  f1-score   support
#
#     kashmir       0.97      1.00      0.98        58
#      others       1.00      0.98      0.99        96
#
# avg / total       0.99      0.99      0.99       154
#
# [[58  0]
#  [ 2 94]]
# PassiveAggressiveClassifier 0.9935064935064936
#              precision    recall  f1-score   support
#
#     kashmir       0.98      1.00      0.99        58
#      others       1.00      0.99      0.99        96
#
# avg / total       0.99      0.99      0.99       154
#
# [[58  0]
#  [ 1 95]]
# KNeighborsClassifier 0.577922077922078
#              precision    recall  f1-score   support
#
#     kashmir       0.47      1.00      0.64        58
#      others       1.00      0.32      0.49        96
#
# avg / total       0.80      0.58      0.55       154
#
# [[58  0]
#  [65 31]]
# RandomForestClassifier 0.935064935064935
#              precision    recall  f1-score   support
#
#     kashmir       1.00      0.83      0.91        58
#      others       0.91      1.00      0.95        96
#
# avg / total       0.94      0.94      0.93       154
#
# [[48 10]
#  [ 0 96]]
# LogisticRegression 0.987012987012987
#              precision    recall  f1-score   support
#
#     kashmir       0.98      0.98      0.98        58
#      others       0.99      0.99      0.99        96
#
# avg / total       0.99      0.99      0.99       154
#
# [[57  1]
#  [ 1 95]]
# LinearSVC 0.9935064935064936
#              precision    recall  f1-score   support
#
#     kashmir       0.98      1.00      0.99        58
#      others       1.00      0.99      0.99        96
#
# avg / total       0.99      0.99      0.99       154
#
# [[58  0]
#  [ 1 95]]
# SGDClassifier 0.9473684210526315
#              precision    recall  f1-score   support
#
#       haiti       0.93      0.97      0.95        94
#      others       0.97      0.93      0.95        96
#
# avg / total       0.95      0.95      0.95       190
#
# [[91  3]
#  [ 7 89]]
# MultinomialNB 0.9263157894736842
#              precision    recall  f1-score   support
#
#       haiti       0.93      0.91      0.92        94
#      others       0.92      0.94      0.93        96
#
# avg / total       0.93      0.93      0.93       190
#
# [[86  8]
#  [ 6 90]]
# PassiveAggressiveClassifier 0.9578947368421052
#              precision    recall  f1-score   support
#
#       haiti       0.93      0.99      0.96        94
#      others       0.99      0.93      0.96        96
#
# avg / total       0.96      0.96      0.96       190
#
# [[93  1]
#  [ 7 89]]
# KNeighborsClassifier 0.7684210526315789
#              precision    recall  f1-score   support
#
#       haiti       0.68      1.00      0.81        94
#      others       1.00      0.54      0.70        96
#
# avg / total       0.84      0.77      0.76       190
#
# [[94  0]
#  [44 52]]
# RandomForestClassifier 0.9315789473684211
#              precision    recall  f1-score   support
#
#       haiti       0.99      0.87      0.93        94
#      others       0.89      0.99      0.94        96
#
# avg / total       0.94      0.93      0.93       190
#
# [[82 12]
#  [ 1 95]]
# LogisticRegression 0.9263157894736842
#              precision    recall  f1-score   support
#
#       haiti       0.97      0.88      0.92        94
#      others       0.89      0.97      0.93        96
#
# avg / total       0.93      0.93      0.93       190
#
# [[83 11]
#  [ 3 93]]
# LinearSVC 0.9473684210526315
#              precision    recall  f1-score   support
#
#       haiti       0.94      0.96      0.95        94
#      others       0.96      0.94      0.95        96
#
# avg / total       0.95      0.95      0.95       190
#
# [[90  4]
#  [ 6 90]]
# SGDClassifier 0.9775280898876404
#              precision    recall  f1-score   support
#
#     sumatra       0.99      0.96      0.98        82
#      others       0.97      0.99      0.98        96
#
# avg / total       0.98      0.98      0.98       178
#
# [[79  3]
#  [ 1 95]]
# MultinomialNB 0.9662921348314607
#              precision    recall  f1-score   support
#
#     sumatra       0.97      0.95      0.96        82
#      others       0.96      0.98      0.97        96
#
# avg / total       0.97      0.97      0.97       178
#
# [[78  4]
#  [ 2 94]]
# PassiveAggressiveClassifier 0.9719101123595506
#              precision    recall  f1-score   support
#
#     sumatra       0.99      0.95      0.97        82
#      others       0.96      0.99      0.97        96
#
# avg / total       0.97      0.97      0.97       178
#
# [[78  4]
#  [ 1 95]]
# KNeighborsClassifier 0.7191011235955056
#              precision    recall  f1-score   support
#
#     sumatra       0.62      0.99      0.76        82
#      others       0.98      0.49      0.65        96
#
# avg / total       0.82      0.72      0.70       178
#
# [[81  1]
#  [49 47]]
# RandomForestClassifier 0.9325842696629213
#              precision    recall  f1-score   support
#
#     sumatra       0.97      0.88      0.92        82
#      others       0.90      0.98      0.94        96
#
# avg / total       0.94      0.93      0.93       178
#
# [[72 10]
#  [ 2 94]]
# LogisticRegression 0.9550561797752809
#              precision    recall  f1-score   support
#
#     sumatra       0.99      0.91      0.95        82
#      others       0.93      0.99      0.96        96
#
# avg / total       0.96      0.96      0.95       178
#
# [[75  7]
#  [ 1 95]]
# LinearSVC 0.9719101123595506
#              precision    recall  f1-score   support
#
#     sumatra       0.99      0.95      0.97        82
#      others       0.96      0.99      0.97        96
#
# avg / total       0.97      0.97      0.97       178
#
# [[78  4]
#  [ 1 95]]
# SGDClassifier 0.9736842105263158
#              precision    recall  f1-score   support
#
#     sichuan       0.99      0.96      0.97        94
#      others       0.96      0.99      0.97        96
#
# avg / total       0.97      0.97      0.97       190
#
# [[90  4]
#  [ 1 95]]
# MultinomialNB 0.9526315789473684
#              precision    recall  f1-score   support
#
#     sichuan       0.95      0.96      0.95        94
#      others       0.96      0.95      0.95        96
#
# avg / total       0.95      0.95      0.95       190
#
# [[90  4]
#  [ 5 91]]
# PassiveAggressiveClassifier 0.9631578947368421
#              precision    recall  f1-score   support
#
#     sichuan       0.94      0.99      0.96        94
#      others       0.99      0.94      0.96        96
#
# avg / total       0.96      0.96      0.96       190
#
# [[93  1]
#  [ 6 90]]
# KNeighborsClassifier 0.6842105263157895
#              precision    recall  f1-score   support
#
#     sichuan       0.61      1.00      0.76        94
#      others       1.00      0.38      0.55        96
#
# avg / total       0.81      0.68      0.65       190
#
# [[94  0]
#  [60 36]]
# RandomForestClassifier 0.9210526315789473
#              precision    recall  f1-score   support
#
#     sichuan       0.98      0.86      0.92        94
#      others       0.88      0.98      0.93        96
#
# avg / total       0.93      0.92      0.92       190
#
# [[81 13]
#  [ 2 94]]
# LogisticRegression 0.9631578947368421
#              precision    recall  f1-score   support
#
#     sichuan       0.98      0.95      0.96        94
#      others       0.95      0.98      0.96        96
#
# avg / total       0.96      0.96      0.96       190
#
# [[89  5]
#  [ 2 94]]
# LinearSVC 0.9736842105263158
#              precision    recall  f1-score   support
#
#     sichuan       0.99      0.96      0.97        94
#      others       0.96      0.99      0.97        96
#
# avg / total       0.97      0.97      0.97       190
#
# [[90  4]
#  [ 1 95]]
# SGDClassifier 0.9795918367346939
#              precision    recall  f1-score   support
#
#      attica       1.00      0.96      0.98       100
#      others       0.96      1.00      0.98        96
#
# avg / total       0.98      0.98      0.98       196
#
# [[96  4]
#  [ 0 96]]
# MultinomialNB 0.9336734693877551
#              precision    recall  f1-score   support
#
#      attica       1.00      0.87      0.93       100
#      others       0.88      1.00      0.94        96
#
# avg / total       0.94      0.93      0.93       196
#
# [[87 13]
#  [ 0 96]]
# PassiveAggressiveClassifier 0.9591836734693877
#              precision    recall  f1-score   support
#
#      attica       0.96      0.96      0.96       100
#      others       0.96      0.96      0.96        96
#
# avg / total       0.96      0.96      0.96       196
#
# [[96  4]
#  [ 4 92]]
# KNeighborsClassifier 0.8826530612244898
#              precision    recall  f1-score   support
#
#      attica       0.98      0.79      0.87       100
#      others       0.82      0.98      0.89        96
#
# avg / total       0.90      0.88      0.88       196
#
# [[79 21]
#  [ 2 94]]
# RandomForestClassifier 0.9591836734693877
#              precision    recall  f1-score   support
#
#      attica       0.97      0.95      0.96       100
#      others       0.95      0.97      0.96        96
#
# avg / total       0.96      0.96      0.96       196
#
# [[95  5]
#  [ 3 93]]
# LogisticRegression 0.9642857142857143
#              precision    recall  f1-score   support
#
#      attica       1.00      0.93      0.96       100
#      others       0.93      1.00      0.96        96
#
# avg / total       0.97      0.96      0.96       196
#
# [[93  7]
#  [ 0 96]]
# LinearSVC 0.9795918367346939
#              precision    recall  f1-score   support
#
#      attica       1.00      0.96      0.98       100
#      others       0.96      1.00      0.98        96
#
# avg / total       0.98      0.98      0.98       196
#
# [[96  4]
#  [ 0 96]]
# SGDClassifier 0.9685863874345549
#              precision    recall  f1-score   support
#
#      nevada       0.94      1.00      0.97        95
#      others       1.00      0.94      0.97        96
#
# avg / total       0.97      0.97      0.97       191
#
# [[95  0]
#  [ 6 90]]
# MultinomialNB 0.9109947643979057
#              precision    recall  f1-score   support
#
#      nevada       0.96      0.85      0.91        95
#      others       0.87      0.97      0.92        96
#
# avg / total       0.92      0.91      0.91       191
#
# [[81 14]
#  [ 3 93]]
# PassiveAggressiveClassifier 0.9267015706806283
#              precision    recall  f1-score   support
#
#      nevada       0.95      0.91      0.92        95
#      others       0.91      0.95      0.93        96
#
# avg / total       0.93      0.93      0.93       191
#
# [[86  9]
#  [ 5 91]]
# KNeighborsClassifier 0.6596858638743456
#              precision    recall  f1-score   support
#
#      nevada       0.60      0.92      0.73        95
#      others       0.83      0.41      0.55        96
#
# avg / total       0.72      0.66      0.64       191
#
# [[87  8]
#  [57 39]]
# RandomForestClassifier 0.8743455497382199
#              precision    recall  f1-score   support
#
#      nevada       0.96      0.78      0.86        95
#      others       0.82      0.97      0.89        96
#
# avg / total       0.89      0.87      0.87       191
#
# [[74 21]
#  [ 3 93]]
# LogisticRegression 0.9109947643979057
#              precision    recall  f1-score   support
#
#      nevada       0.96      0.85      0.91        95
#      others       0.87      0.97      0.92        96
#
# avg / total       0.92      0.91      0.91       191
#
# [[81 14]
#  [ 3 93]]
# LinearSVC 0.9528795811518325
#              precision    recall  f1-score   support
#
#      nevada       0.97      0.94      0.95        95
#      others       0.94      0.97      0.95        96
#
# avg / total       0.95      0.95      0.95       191
#
# [[89  6]
#  [ 3 93]]
# SGDClassifier 0.9431818181818182
#              precision    recall  f1-score   support
#
#      thomas       0.99      0.89      0.93        80
#      others       0.91      0.99      0.95        96
#
# avg / total       0.95      0.94      0.94       176
#
# [[71  9]
#  [ 1 95]]
# MultinomialNB 0.9261363636363636
#              precision    recall  f1-score   support
#
#      thomas       0.95      0.89      0.92        80
#      others       0.91      0.96      0.93        96
#
# avg / total       0.93      0.93      0.93       176
#
# [[71  9]
#  [ 4 92]]
# PassiveAggressiveClassifier 0.9431818181818182
#              precision    recall  f1-score   support
#
#      thomas       0.99      0.89      0.93        80
#      others       0.91      0.99      0.95        96
#
# avg / total       0.95      0.94      0.94       176
#
# [[71  9]
#  [ 1 95]]
# KNeighborsClassifier 0.875
#              precision    recall  f1-score   support
#
#      thomas       0.86      0.86      0.86        80
#      others       0.89      0.89      0.89        96
#
# avg / total       0.88      0.88      0.88       176
#
# [[69 11]
#  [11 85]]
# RandomForestClassifier 0.9204545454545454
#              precision    recall  f1-score   support
#
#      thomas       1.00      0.82      0.90        80
#      others       0.87      1.00      0.93        96
#
# avg / total       0.93      0.92      0.92       176
#
# [[66 14]
#  [ 0 96]]
# LogisticRegression 0.9318181818181818
#              precision    recall  f1-score   support
#
#      thomas       0.97      0.88      0.92        80
#      others       0.90      0.98      0.94        96
#
# avg / total       0.93      0.93      0.93       176
#
# [[70 10]
#  [ 2 94]]
# LinearSVC 0.9488636363636364
#              precision    recall  f1-score   support
#
#      thomas       1.00      0.89      0.94        80
#      others       0.91      1.00      0.96        96
#
# avg / total       0.95      0.95      0.95       176
#
# [[71  9]
#  [ 0 96]]
# SGDClassifier 0.9526315789473684
#              precision    recall  f1-score   support
#
#       maria       0.98      0.93      0.95        94
#      others       0.93      0.98      0.95        96
#
# avg / total       0.95      0.95      0.95       190
#
# [[87  7]
#  [ 2 94]]
# MultinomialNB 0.9526315789473684
#              precision    recall  f1-score   support
#
#       maria       0.99      0.91      0.95        94
#      others       0.92      0.99      0.95        96
#
# avg / total       0.96      0.95      0.95       190
#
# [[86  8]
#  [ 1 95]]
# PassiveAggressiveClassifier 0.9578947368421052
#              precision    recall  f1-score   support
#
#       maria       0.99      0.93      0.96        94
#      others       0.93      0.99      0.96        96
#
# avg / total       0.96      0.96      0.96       190
#
# [[87  7]
#  [ 1 95]]
# KNeighborsClassifier 0.8210526315789474
#              precision    recall  f1-score   support
#
#       maria       0.78      0.89      0.83        94
#      others       0.88      0.75      0.81        96
#
# avg / total       0.83      0.82      0.82       190
#
# [[84 10]
#  [24 72]]
# RandomForestClassifier 0.9
#              precision    recall  f1-score   support
#
#       maria       1.00      0.80      0.89        94
#      others       0.83      1.00      0.91        96
#
# avg / total       0.92      0.90      0.90       190
#
# [[75 19]
#  [ 0 96]]
# LogisticRegression 0.9263157894736842
#              precision    recall  f1-score   support
#
#       maria       0.99      0.86      0.92        94
#      others       0.88      0.99      0.93        96
#
# avg / total       0.93      0.93      0.93       190
#
# [[81 13]
#  [ 1 95]]
# LinearSVC 0.9526315789473684
#              precision    recall  f1-score   support
#
#       maria       0.98      0.93      0.95        94
#      others       0.93      0.98      0.95        96
#
# avg / total       0.95      0.95      0.95       190
#
# [[87  7]
#  [ 2 94]]
# SGDClassifier 0.9890710382513661
#              precision    recall  f1-score   support
#
#     katrina       0.99      0.99      0.99        87
#      others       0.99      0.99      0.99        96
#
# avg / total       0.99      0.99      0.99       183
#
# [[86  1]
#  [ 1 95]]
# MultinomialNB 0.9016393442622951
#              precision    recall  f1-score   support
#
#     katrina       0.99      0.80      0.89        87
#      others       0.85      0.99      0.91        96
#
# avg / total       0.91      0.90      0.90       183
#
# [[70 17]
#  [ 1 95]]
# PassiveAggressiveClassifier 0.9836065573770492
#              precision    recall  f1-score   support
#
#     katrina       0.97      1.00      0.98        87
#      others       1.00      0.97      0.98        96
#
# avg / total       0.98      0.98      0.98       183
#
# [[87  0]
#  [ 3 93]]
# KNeighborsClassifier 0.8907103825136612
#              precision    recall  f1-score   support
#
#     katrina       0.81      1.00      0.90        87
#      others       1.00      0.79      0.88        96
#
# avg / total       0.91      0.89      0.89       183
#
# [[87  0]
#  [20 76]]
# RandomForestClassifier 0.8907103825136612
#              precision    recall  f1-score   support
#
#     katrina       1.00      0.77      0.87        87
#      others       0.83      1.00      0.91        96
#
# avg / total       0.91      0.89      0.89       183
#
# [[67 20]
#  [ 0 96]]
# LogisticRegression 0.9398907103825137
#              precision    recall  f1-score   support
#
#     katrina       0.99      0.89      0.93        87
#      others       0.90      0.99      0.95        96
#
# avg / total       0.94      0.94      0.94       183
#
# [[77 10]
#  [ 1 95]]
# LinearSVC 0.9781420765027322
#              precision    recall  f1-score   support
#
#     katrina       0.98      0.98      0.98        87
#      others       0.98      0.98      0.98        96
#
# avg / total       0.98      0.98      0.98       183
#
# [[85  2]
#  [ 2 94]]
