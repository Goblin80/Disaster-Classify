# %%
import sys
import glob
import numpy
from random import shuffle

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.pipeline import Pipeline
from nltk.stem.snowball import EnglishStemmer

from sklearn.linear_model import SGDClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import PassiveAggressiveClassifier

from sklearn.neighbors import KNeighborsClassifier

from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC

from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %%
def sz(a): # str/eval
    return {
        'text': a.text,
        'title': a.title,
        'url': a.url,
        'keywords': a.keywords,
        'tags': a.tags,
        'summary': a.summary,
        'date': int(a.publish_date.timestamp()) if a.publish_date != None else None,
        'raw' : a.html
    }

# %%
def objRead(f):
    return eval(open(f, 'r').read())

def objWrite(f, data):
    f = f.split('.')[0]
    open(f + '.lobj', 'w').write(str(data)) # light obj

# %%
for f in glob.iglob('**/*.lobj', recursive=True):
    print(f)
# Out:
# other.lobj
# disasters/shootings/sandyhook.lobj
# disasters/shootings/orlando.lobj
# disasters/shootings/lasvegas.lobj
# disasters/shootings/sanbernardino.lobj
# disasters/earthquakes/sumatra.lobj
# disasters/earthquakes/haiti.lobj
# disasters/earthquakes/sichuan.lobj
# disasters/earthquakes/kashmir.lobj
# disasters/wildfires/thomas.lobj
# disasters/wildfires/attica.lobj
# disasters/wildfires/mountcarmel.lobj
# disasters/wildfires/nevada.lobj
# disasters/hurricanes/jeanne.lobj
# disasters/hurricanes/stan.lobj
# disasters/hurricanes/maria.lobj
# disasters/hurricanes/katrina.lobj

# %%
data = [
    { 'articles': objRead('disasters/shootings/lasvegas.lobj'), 'label': 'lasvegas' },
    { 'articles': objRead('disasters/shootings/orlando.lobj'), 'label': 'orlando' },
    { 'articles': objRead('disasters/shootings/sandyhook.lobj'), 'label': 'sandyhook' },
    { 'articles': objRead('disasters/shootings/sanbernardino.lobj'), 'label': 'sanbernardino' },
    { 'articles': objRead('disasters/earthquakes/kashmir.lobj'), 'label': 'kashmir' },
    { 'articles': objRead('disasters/earthquakes/haiti.lobj'), 'label': 'haiti' },
    { 'articles': objRead('disasters/earthquakes/sumatra.lobj'), 'label': 'sumatra' },
    { 'articles': objRead('disasters/earthquakes/sichuan.lobj'), 'label': 'sichuan' },
#     { 'articles': objRead('disasters/wildfires/mountcarmel.lobj'), 'label': 'mountcarmel' }, # only 19 articles
    { 'articles': objRead('disasters/wildfires/attica.lobj'), 'label': 'attica' },
    { 'articles': objRead('disasters/wildfires/nevada.lobj'), 'label': 'nevada' },
    { 'articles': objRead('disasters/wildfires/thomas.lobj'), 'label': 'thomas' },
    { 'articles': objRead('disasters/hurricanes/maria.lobj'), 'label': 'maria' },
    { 'articles': objRead('disasters/hurricanes/katrina.lobj'), 'label': 'katrina' }
#     { 'articles': objRead('disasters/hurricanes/jeanne.lobj'), 'label': 'jeanne' }, # only 35 articles
#     { 'articles': objRead('disasters/hurricanes/stan.lobj'), 'label': 'stan'} # only 29 articles
]

labels = [x['label'] for x in data]

# %%
classifiers = [
    SGDClassifier(loss='hinge',
                  penalty='elasticnet',
                  alpha=1e-3,
                  max_iter=1000,
                  tol=None),
    MultinomialNB(),
    PassiveAggressiveClassifier(max_iter=200),
    KNeighborsClassifier(n_neighbors=len(data)),
    RandomForestClassifier(n_estimators=200,
                           max_depth=3),
    LogisticRegression(),
    LinearSVC()
]

# %%
stemmer = EnglishStemmer()
analyzer = CountVectorizer().build_analyzer()

def stemmed_words(text):
    return (stemmer.stem(word) for word in analyzer(text))

# stem_vectorizer = CountVectorizer(analyzer=stemmed_words)
# print(stem_vectorizer.fit_transform(['analyst does analysis']))
# print(stem_vectorizer.get_feature_names())

# %%
for label in labels:    
    train_data, test_data = [], []
    train_label, test_label = numpy.array([]), numpy.array([])

    TRAIN_SIZE = 40

    for cat in data:
        l = int(cat['label'] != label)
        shuffle(cat['articles'])
        
        s = 0
        for x in cat['articles'][:TRAIN_SIZE]:
            if 'washingtonpost' in x['url']:
                continue
                
            if l:
                if s > 1.25 * TRAIN_SIZE / len(data):
                    break
                s += 1
                
            train_data.append(x['text'])
            train_label = numpy.append(train_label, l)
            
        s = 0
        for x in cat['articles'][TRAIN_SIZE:]:
            if 'washingtonpost' in x['url']:
                continue
                
            if l:
                if s > 1.25 * TRAIN_SIZE / len(data):
                    break
                s += 1
                
            test_data.append(x['text'])
            test_label = numpy.append(test_label, l)
            
    test_data += train_data
    test_label = numpy.append(test_label, train_label)
    
    for c in classifiers:
        clf = Pipeline([('vect', CountVectorizer(analyzer=stemmed_words,
                                                 stop_words='english')),
                        ('tfidf', TfidfTransformer()),
                        ('clf', c),
        ])
        clf.fit(train_data, train_label)
                
        pred_label = clf.predict(test_data)
        print(type(c).__name__, accuracy_score(test_label, pred_label))
        print(classification_report(test_label, pred_label, target_names = [label, 'others']))
        print(confusion_matrix(test_label, pred_label))
# Out:
# SGDClassifier 0.9259259259259259
#              precision    recall  f1-score   support
#
#    lasvegas       1.00      0.85      0.92        93
#      others       0.87      1.00      0.93        96
#
# avg / total       0.94      0.93      0.93       189
#
# [[79 14]
#  [ 0 96]]
# MultinomialNB 0.9153439153439153
#              precision    recall  f1-score   support
#
#    lasvegas       0.96      0.86      0.91        93
#      others       0.88      0.97      0.92        96
#
# avg / total       0.92      0.92      0.92       189
#
# [[80 13]
#  [ 3 93]]
# PassiveAggressiveClassifier 0.9312169312169312
#              precision    recall  f1-score   support
#
#    lasvegas       1.00      0.86      0.92        93
#      others       0.88      1.00      0.94        96
#
# avg / total       0.94      0.93      0.93       189
#
# [[80 13]
#  [ 0 96]]
# KNeighborsClassifier 0.7619047619047619
#              precision    recall  f1-score   support
#
#    lasvegas       0.69      0.94      0.79        93
#      others       0.90      0.59      0.72        96
#
# avg / total       0.80      0.76      0.76       189
#
# [[87  6]
#  [39 57]]
# RandomForestClassifier 0.8994708994708994
#              precision    recall  f1-score   support
#
#    lasvegas       1.00      0.80      0.89        93
#      others       0.83      1.00      0.91        96
#
# avg / total       0.92      0.90      0.90       189
#
# [[74 19]
#  [ 0 96]]
# LogisticRegression 0.8941798941798942
#              precision    recall  f1-score   support
#
#    lasvegas       1.00      0.78      0.88        93
#      others       0.83      1.00      0.91        96
#
# avg / total       0.91      0.89      0.89       189
#
# [[73 20]
#  [ 0 96]]
# LinearSVC 0.9206349206349206
#              precision    recall  f1-score   support
#
#    lasvegas       1.00      0.84      0.91        93
#      others       0.86      1.00      0.93        96
#
# avg / total       0.93      0.92      0.92       189
#
# [[78 15]
#  [ 0 96]]
# SGDClassifier 0.9572192513368984
#              precision    recall  f1-score   support
#
#     orlando       1.00      0.91      0.95        91
#      others       0.92      1.00      0.96        96
#
# avg / total       0.96      0.96      0.96       187
#
# [[83  8]
#  [ 0 96]]
# MultinomialNB 0.9679144385026738
#              precision    recall  f1-score   support
#
#     orlando       1.00      0.93      0.97        91
#      others       0.94      1.00      0.97        96
#
# avg / total       0.97      0.97      0.97       187
#
# [[85  6]
#  [ 0 96]]
# PassiveAggressiveClassifier 0.9625668449197861
#              precision    recall  f1-score   support
#
#     orlando       1.00      0.92      0.96        91
#      others       0.93      1.00      0.96        96
#
# avg / total       0.97      0.96      0.96       187
#
# [[84  7]
#  [ 0 96]]
# KNeighborsClassifier 0.6684491978609626
#              precision    recall  f1-score   support
#
#     orlando       0.60      0.98      0.74        91
#      others       0.95      0.38      0.54        96
#
# avg / total       0.78      0.67      0.64       187
#
# [[89  2]
#  [60 36]]
# RandomForestClassifier 0.946524064171123
#              precision    recall  f1-score   support
#
#     orlando       1.00      0.89      0.94        91
#      others       0.91      1.00      0.95        96
#
# avg / total       0.95      0.95      0.95       187
#
# [[81 10]
#  [ 0 96]]
# LogisticRegression 0.9358288770053476
#              precision    recall  f1-score   support
#
#     orlando       1.00      0.87      0.93        91
#      others       0.89      1.00      0.94        96
#
# avg / total       0.94      0.94      0.94       187
#
# [[79 12]
#  [ 0 96]]
# LinearSVC 0.9518716577540107
#              precision    recall  f1-score   support
#
#     orlando       1.00      0.90      0.95        91
#      others       0.91      1.00      0.96        96
#
# avg / total       0.96      0.95      0.95       187
#
# [[82  9]
#  [ 0 96]]
# SGDClassifier 0.9790575916230366
#              precision    recall  f1-score   support
#
#   sandyhook       0.97      0.99      0.98        95
#      others       0.99      0.97      0.98        96
#
# avg / total       0.98      0.98      0.98       191
#
# [[94  1]
#  [ 3 93]]
# MultinomialNB 0.9738219895287958
#              precision    recall  f1-score   support
#
#   sandyhook       0.97      0.98      0.97        95
#      others       0.98      0.97      0.97        96
#
# avg / total       0.97      0.97      0.97       191
#
# [[93  2]
#  [ 3 93]]
# PassiveAggressiveClassifier 0.9790575916230366
#              precision    recall  f1-score   support
#
#   sandyhook       0.96      1.00      0.98        95
#      others       1.00      0.96      0.98        96
#
# avg / total       0.98      0.98      0.98       191
#
# [[95  0]
#  [ 4 92]]
# KNeighborsClassifier 0.9424083769633508
#              precision    recall  f1-score   support
#
#   sandyhook       0.90      1.00      0.95        95
#      others       1.00      0.89      0.94        96
#
# avg / total       0.95      0.94      0.94       191
#
# [[95  0]
#  [11 85]]
# RandomForestClassifier 0.93717277486911
#              precision    recall  f1-score   support
#
#   sandyhook       1.00      0.87      0.93        95
#      others       0.89      1.00      0.94        96
#
# avg / total       0.94      0.94      0.94       191
#
# [[83 12]
#  [ 0 96]]
# LogisticRegression 0.9685863874345549
#              precision    recall  f1-score   support
#
#   sandyhook       0.97      0.97      0.97        95
#      others       0.97      0.97      0.97        96
#
# avg / total       0.97      0.97      0.97       191
#
# [[92  3]
#  [ 3 93]]
# LinearSVC 0.9738219895287958
#              precision    recall  f1-score   support
#
#   sandyhook       0.97      0.98      0.97        95
#      others       0.98      0.97      0.97        96
#
# avg / total       0.97      0.97      0.97       191
#
# [[93  2]
#  [ 3 93]]
# SGDClassifier 0.9585492227979274
#                precision    recall  f1-score   support
#
# sanbernardino       0.95      0.97      0.96        97
#        others       0.97      0.95      0.96        96
#
#   avg / total       0.96      0.96      0.96       193
#
# [[94  3]
#  [ 5 91]]
# MultinomialNB 0.9430051813471503
#                precision    recall  f1-score   support
#
# sanbernardino       0.97      0.92      0.94        97
#        others       0.92      0.97      0.94        96
#
#   avg / total       0.94      0.94      0.94       193
#
# [[89  8]
#  [ 3 93]]
# PassiveAggressiveClassifier 0.9481865284974094
#                precision    recall  f1-score   support
#
# sanbernardino       1.00      0.90      0.95        97
#        others       0.91      1.00      0.95        96
#
#   avg / total       0.95      0.95      0.95       193
#
# [[87 10]
#  [ 0 96]]
# KNeighborsClassifier 0.689119170984456
#                precision    recall  f1-score   support
#
# sanbernardino       0.62      0.96      0.76        97
#        others       0.91      0.42      0.57        96
#
#   avg / total       0.77      0.69      0.66       193
#
# [[93  4]
#  [56 40]]
# RandomForestClassifier 0.9326424870466321
#                precision    recall  f1-score   support
#
# sanbernardino       1.00      0.87      0.93        97
#        others       0.88      1.00      0.94        96
#
#   avg / total       0.94      0.93      0.93       193
#
# [[84 13]
#  [ 0 96]]
# LogisticRegression 0.9326424870466321
#                precision    recall  f1-score   support
#
# sanbernardino       1.00      0.87      0.93        97
#        others       0.88      1.00      0.94        96
#
#   avg / total       0.94      0.93      0.93       193
#
# [[84 13]
#  [ 0 96]]
# LinearSVC 0.9637305699481865
#                precision    recall  f1-score   support
#
# sanbernardino       0.96      0.97      0.96        97
#        others       0.97      0.96      0.96        96
#
#   avg / total       0.96      0.96      0.96       193
#
# [[94  3]
#  [ 4 92]]
# SGDClassifier 1.0
#              precision    recall  f1-score   support
#
#     kashmir       1.00      1.00      1.00        58
#      others       1.00      1.00      1.00        96
#
# avg / total       1.00      1.00      1.00       154
#
# [[58  0]
#  [ 0 96]]
# MultinomialNB 1.0
#              precision    recall  f1-score   support
#
#     kashmir       1.00      1.00      1.00        58
#      others       1.00      1.00      1.00        96
#
# avg / total       1.00      1.00      1.00       154
#
# [[58  0]
#  [ 0 96]]
# PassiveAggressiveClassifier 0.9935064935064936
#              precision    recall  f1-score   support
#
#     kashmir       0.98      1.00      0.99        58
#      others       1.00      0.99      0.99        96
#
# avg / total       0.99      0.99      0.99       154
#
# [[58  0]
#  [ 1 95]]
# KNeighborsClassifier 0.525974025974026
#              precision    recall  f1-score   support
#
#     kashmir       0.44      1.00      0.61        58
#      others       1.00      0.24      0.39        96
#
# avg / total       0.79      0.53      0.47       154
#
# [[58  0]
#  [73 23]]
# RandomForestClassifier 0.9675324675324676
#              precision    recall  f1-score   support
#
#     kashmir       1.00      0.91      0.95        58
#      others       0.95      1.00      0.97        96
#
# avg / total       0.97      0.97      0.97       154
#
# [[53  5]
#  [ 0 96]]
# LogisticRegression 0.9935064935064936
#              precision    recall  f1-score   support
#
#     kashmir       1.00      0.98      0.99        58
#      others       0.99      1.00      0.99        96
#
# avg / total       0.99      0.99      0.99       154
#
# [[57  1]
#  [ 0 96]]
# LinearSVC 1.0
#              precision    recall  f1-score   support
#
#     kashmir       1.00      1.00      1.00        58
#      others       1.00      1.00      1.00        96
#
# avg / total       1.00      1.00      1.00       154
#
# [[58  0]
#  [ 0 96]]
# SGDClassifier 0.9578947368421052
#              precision    recall  f1-score   support
#
#       haiti       0.99      0.93      0.96        94
#      others       0.93      0.99      0.96        96
#
# avg / total       0.96      0.96      0.96       190
#
# [[87  7]
#  [ 1 95]]
# MultinomialNB 0.9368421052631579
#              precision    recall  f1-score   support
#
#       haiti       0.95      0.93      0.94        94
#      others       0.93      0.95      0.94        96
#
# avg / total       0.94      0.94      0.94       190
#
# [[87  7]
#  [ 5 91]]
# PassiveAggressiveClassifier 0.9631578947368421
#              precision    recall  f1-score   support
#
#       haiti       0.99      0.94      0.96        94
#      others       0.94      0.99      0.96        96
#
# avg / total       0.96      0.96      0.96       190
#
# [[88  6]
#  [ 1 95]]
# KNeighborsClassifier 0.6947368421052632
#              precision    recall  f1-score   support
#
#       haiti       0.62      0.97      0.76        94
#      others       0.93      0.43      0.59        96
#
# avg / total       0.78      0.69      0.67       190
#
# [[91  3]
#  [55 41]]
# RandomForestClassifier 0.9263157894736842
#              precision    recall  f1-score   support
#
#       haiti       0.99      0.86      0.92        94
#      others       0.88      0.99      0.93        96
#
# avg / total       0.93      0.93      0.93       190
#
# [[81 13]
#  [ 1 95]]
# LogisticRegression 0.9368421052631579
#              precision    recall  f1-score   support
#
#       haiti       0.99      0.88      0.93        94
#      others       0.90      0.99      0.94        96
#
# avg / total       0.94      0.94      0.94       190
#
# [[83 11]
#  [ 1 95]]
# LinearSVC 0.9526315789473684
#              precision    recall  f1-score   support
#
#       haiti       0.99      0.91      0.95        94
#      others       0.92      0.99      0.95        96
#
# avg / total       0.96      0.95      0.95       190
#
# [[86  8]
#  [ 1 95]]
# SGDClassifier 0.9887640449438202
#              precision    recall  f1-score   support
#
#     sumatra       1.00      0.98      0.99        82
#      others       0.98      1.00      0.99        96
#
# avg / total       0.99      0.99      0.99       178
#
# [[80  2]
#  [ 0 96]]
# MultinomialNB 0.9662921348314607
#              precision    recall  f1-score   support
#
#     sumatra       1.00      0.93      0.96        82
#      others       0.94      1.00      0.97        96
#
# avg / total       0.97      0.97      0.97       178
#
# [[76  6]
#  [ 0 96]]
# PassiveAggressiveClassifier 0.9831460674157303
#              precision    recall  f1-score   support
#
#     sumatra       1.00      0.96      0.98        82
#      others       0.97      1.00      0.98        96
#
# avg / total       0.98      0.98      0.98       178
#
# [[79  3]
#  [ 0 96]]
# KNeighborsClassifier 0.8146067415730337
#              precision    recall  f1-score   support
#
#     sumatra       0.72      0.99      0.83        82
#      others       0.98      0.67      0.80        96
#
# avg / total       0.86      0.81      0.81       178
#
# [[81  1]
#  [32 64]]
# RandomForestClassifier 0.9157303370786517
#              precision    recall  f1-score   support
#
#     sumatra       1.00      0.82      0.90        82
#      others       0.86      1.00      0.93        96
#
# avg / total       0.93      0.92      0.91       178
#
# [[67 15]
#  [ 0 96]]
# LogisticRegression 0.949438202247191
#              precision    recall  f1-score   support
#
#     sumatra       1.00      0.89      0.94        82
#      others       0.91      1.00      0.96        96
#
# avg / total       0.95      0.95      0.95       178
#
# [[73  9]
#  [ 0 96]]
# LinearSVC 0.9775280898876404
#              precision    recall  f1-score   support
#
#     sumatra       1.00      0.95      0.97        82
#      others       0.96      1.00      0.98        96
#
# avg / total       0.98      0.98      0.98       178
#
# [[78  4]
#  [ 0 96]]
# SGDClassifier 0.9578947368421052
#              precision    recall  f1-score   support
#
#     sichuan       1.00      0.91      0.96        94
#      others       0.92      1.00      0.96        96
#
# avg / total       0.96      0.96      0.96       190
#
# [[86  8]
#  [ 0 96]]
# MultinomialNB 0.9631578947368421
#              precision    recall  f1-score   support
#
#     sichuan       1.00      0.93      0.96        94
#      others       0.93      1.00      0.96        96
#
# avg / total       0.97      0.96      0.96       190
#
# [[87  7]
#  [ 0 96]]
# PassiveAggressiveClassifier 0.9736842105263158
#              precision    recall  f1-score   support
#
#     sichuan       1.00      0.95      0.97        94
#      others       0.95      1.00      0.97        96
#
# avg / total       0.97      0.97      0.97       190
#
# [[89  5]
#  [ 0 96]]
# KNeighborsClassifier 0.631578947368421
#              precision    recall  f1-score   support
#
#     sichuan       0.57      1.00      0.73        94
#      others       1.00      0.27      0.43        96
#
# avg / total       0.79      0.63      0.58       190
#
# [[94  0]
#  [70 26]]
# RandomForestClassifier 0.9105263157894737
#              precision    recall  f1-score   support
#
#     sichuan       0.98      0.84      0.90        94
#      others       0.86      0.98      0.92        96
#
# avg / total       0.92      0.91      0.91       190
#
# [[79 15]
#  [ 2 94]]
# LogisticRegression 0.9421052631578948
#              precision    recall  f1-score   support
#
#     sichuan       0.99      0.89      0.94        94
#      others       0.90      0.99      0.95        96
#
# avg / total       0.95      0.94      0.94       190
#
# [[84 10]
#  [ 1 95]]
# LinearSVC 0.9526315789473684
#              precision    recall  f1-score   support
#
#     sichuan       1.00      0.90      0.95        94
#      others       0.91      1.00      0.96        96
#
# avg / total       0.96      0.95      0.95       190
#
# [[85  9]
#  [ 0 96]]
# SGDClassifier 0.9642857142857143
#              precision    recall  f1-score   support
#
#      attica       0.99      0.94      0.96       100
#      others       0.94      0.99      0.96        96
#
# avg / total       0.97      0.96      0.96       196
#
# [[94  6]
#  [ 1 95]]
# MultinomialNB 0.9438775510204082
#              precision    recall  f1-score   support
#
#      attica       1.00      0.89      0.94       100
#      others       0.90      1.00      0.95        96
#
# avg / total       0.95      0.94      0.94       196
#
# [[89 11]
#  [ 0 96]]
# PassiveAggressiveClassifier 0.9744897959183674
#              precision    recall  f1-score   support
#
#      attica       0.97      0.98      0.98       100
#      others       0.98      0.97      0.97        96
#
# avg / total       0.97      0.97      0.97       196
#
# [[98  2]
#  [ 3 93]]
# KNeighborsClassifier 0.8520408163265306
#              precision    recall  f1-score   support
#
#      attica       0.97      0.73      0.83       100
#      others       0.78      0.98      0.87        96
#
# avg / total       0.88      0.85      0.85       196
#
# [[73 27]
#  [ 2 94]]
# RandomForestClassifier 0.9642857142857143
#              precision    recall  f1-score   support
#
#      attica       1.00      0.93      0.96       100
#      others       0.93      1.00      0.96        96
#
# avg / total       0.97      0.96      0.96       196
#
# [[93  7]
#  [ 0 96]]
# LogisticRegression 0.9540816326530612
#              precision    recall  f1-score   support
#
#      attica       1.00      0.91      0.95       100
#      others       0.91      1.00      0.96        96
#
# avg / total       0.96      0.95      0.95       196
#
# [[91  9]
#  [ 0 96]]
# LinearSVC 0.9744897959183674
#              precision    recall  f1-score   support
#
#      attica       1.00      0.95      0.97       100
#      others       0.95      1.00      0.97        96
#
# avg / total       0.98      0.97      0.97       196
#
# [[95  5]
#  [ 0 96]]
# SGDClassifier 0.9738219895287958
#              precision    recall  f1-score   support
#
#      nevada       0.97      0.98      0.97        95
#      others       0.98      0.97      0.97        96
#
# avg / total       0.97      0.97      0.97       191
#
# [[93  2]
#  [ 3 93]]
# MultinomialNB 0.9214659685863874
#              precision    recall  f1-score   support
#
#      nevada       0.94      0.89      0.92        95
#      others       0.90      0.95      0.92        96
#
# avg / total       0.92      0.92      0.92       191
#
# [[85 10]
#  [ 5 91]]
# PassiveAggressiveClassifier 0.9424083769633508
#              precision    recall  f1-score   support
#
#      nevada       0.98      0.91      0.94        95
#      others       0.91      0.98      0.94        96
#
# avg / total       0.94      0.94      0.94       191
#
# [[86  9]
#  [ 2 94]]
# KNeighborsClassifier 0.8429319371727748
#              precision    recall  f1-score   support
#
#      nevada       0.84      0.85      0.84        95
#      others       0.85      0.83      0.84        96
#
# avg / total       0.84      0.84      0.84       191
#
# [[81 14]
#  [16 80]]
# RandomForestClassifier 0.8952879581151832
#              precision    recall  f1-score   support
#
#      nevada       0.97      0.81      0.89        95
#      others       0.84      0.98      0.90        96
#
# avg / total       0.91      0.90      0.89       191
#
# [[77 18]
#  [ 2 94]]
# LogisticRegression 0.9214659685863874
#              precision    recall  f1-score   support
#
#      nevada       0.94      0.89      0.92        95
#      others       0.90      0.95      0.92        96
#
# avg / total       0.92      0.92      0.92       191
#
# [[85 10]
#  [ 5 91]]
# LinearSVC 0.9738219895287958
#              precision    recall  f1-score   support
#
#      nevada       0.97      0.98      0.97        95
#      others       0.98      0.97      0.97        96
#
# avg / total       0.97      0.97      0.97       191
#
# [[93  2]
#  [ 3 93]]
# SGDClassifier 0.9431818181818182
#              precision    recall  f1-score   support
#
#      thomas       0.95      0.93      0.94        80
#      others       0.94      0.96      0.95        96
#
# avg / total       0.94      0.94      0.94       176
#
# [[74  6]
#  [ 4 92]]
# MultinomialNB 0.9147727272727273
#              precision    recall  f1-score   support
#
#      thomas       0.96      0.85      0.90        80
#      others       0.89      0.97      0.93        96
#
# avg / total       0.92      0.91      0.91       176
#
# [[68 12]
#  [ 3 93]]
# PassiveAggressiveClassifier 0.9204545454545454
#              precision    recall  f1-score   support
#
#      thomas       0.96      0.86      0.91        80
#      others       0.89      0.97      0.93        96
#
# avg / total       0.92      0.92      0.92       176
#
# [[69 11]
#  [ 3 93]]
# KNeighborsClassifier 0.8920454545454546
#              precision    recall  f1-score   support
#
#      thomas       0.88      0.89      0.88        80
#      others       0.91      0.90      0.90        96
#
# avg / total       0.89      0.89      0.89       176
#
# [[71  9]
#  [10 86]]
# RandomForestClassifier 0.9147727272727273
#              precision    recall  f1-score   support
#
#      thomas       0.99      0.82      0.90        80
#      others       0.87      0.99      0.93        96
#
# avg / total       0.92      0.91      0.91       176
#
# [[66 14]
#  [ 1 95]]
# LogisticRegression 0.8977272727272727
#              precision    recall  f1-score   support
#
#      thomas       0.96      0.81      0.88        80
#      others       0.86      0.97      0.91        96
#
# avg / total       0.90      0.90      0.90       176
#
# [[65 15]
#  [ 3 93]]
# LinearSVC 0.9431818181818182
#              precision    recall  f1-score   support
#
#      thomas       0.95      0.93      0.94        80
#      others       0.94      0.96      0.95        96
#
# avg / total       0.94      0.94      0.94       176
#
# [[74  6]
#  [ 4 92]]
# SGDClassifier 0.9473684210526315
#              precision    recall  f1-score   support
#
#       maria       0.99      0.90      0.94        94
#      others       0.91      0.99      0.95        96
#
# avg / total       0.95      0.95      0.95       190
#
# [[85  9]
#  [ 1 95]]
# MultinomialNB 0.9263157894736842
#              precision    recall  f1-score   support
#
#       maria       1.00      0.85      0.92        94
#      others       0.87      1.00      0.93        96
#
# avg / total       0.94      0.93      0.93       190
#
# [[80 14]
#  [ 0 96]]
# PassiveAggressiveClassifier 0.968421052631579
#              precision    recall  f1-score   support
#
#       maria       0.99      0.95      0.97        94
#      others       0.95      0.99      0.97        96
#
# avg / total       0.97      0.97      0.97       190
#
# [[89  5]
#  [ 1 95]]
# KNeighborsClassifier 0.7368421052631579
#              precision    recall  f1-score   support
#
#       maria       0.65      0.99      0.79        94
#      others       0.98      0.49      0.65        96
#
# avg / total       0.82      0.74      0.72       190
#
# [[93  1]
#  [49 47]]
# RandomForestClassifier 0.8947368421052632
#              precision    recall  f1-score   support
#
#       maria       1.00      0.79      0.88        94
#      others       0.83      1.00      0.91        96
#
# avg / total       0.91      0.89      0.89       190
#
# [[74 20]
#  [ 0 96]]
# LogisticRegression 0.9157894736842105
#              precision    recall  f1-score   support
#
#       maria       1.00      0.83      0.91        94
#      others       0.86      1.00      0.92        96
#
# avg / total       0.93      0.92      0.92       190
#
# [[78 16]
#  [ 0 96]]
# LinearSVC 0.9368421052631579
#              precision    recall  f1-score   support
#
#       maria       0.99      0.88      0.93        94
#      others       0.90      0.99      0.94        96
#
# avg / total       0.94      0.94      0.94       190
#
# [[83 11]
#  [ 1 95]]
# SGDClassifier 0.9890710382513661
#              precision    recall  f1-score   support
#
#     katrina       0.99      0.99      0.99        87
#      others       0.99      0.99      0.99        96
#
# avg / total       0.99      0.99      0.99       183
#
# [[86  1]
#  [ 1 95]]
# MultinomialNB 0.7486338797814208
#              precision    recall  f1-score   support
#
#     katrina       0.98      0.48      0.65        87
#      others       0.68      0.99      0.81        96
#
# avg / total       0.82      0.75      0.73       183
#
# [[42 45]
#  [ 1 95]]
# PassiveAggressiveClassifier 0.9890710382513661
#              precision    recall  f1-score   support
#
#     katrina       0.99      0.99      0.99        87
#      others       0.99      0.99      0.99        96
#
# avg / total       0.99      0.99      0.99       183
#
# [[86  1]
#  [ 1 95]]
# KNeighborsClassifier 0.7923497267759563
#              precision    recall  f1-score   support
#
#     katrina       0.70      1.00      0.82        87
#      others       1.00      0.60      0.75        96
#
# avg / total       0.86      0.79      0.79       183
#
# [[87  0]
#  [38 58]]
# RandomForestClassifier 0.8852459016393442
#              precision    recall  f1-score   support
#
#     katrina       0.99      0.77      0.86        87
#      others       0.83      0.99      0.90        96
#
# avg / total       0.90      0.89      0.88       183
#
# [[67 20]
#  [ 1 95]]
# LogisticRegression 0.8524590163934426
#              precision    recall  f1-score   support
#
#     katrina       0.98      0.70      0.82        87
#      others       0.79      0.99      0.88        96
#
# avg / total       0.88      0.85      0.85       183
#
# [[61 26]
#  [ 1 95]]
# LinearSVC 0.9672131147540983
#              precision    recall  f1-score   support
#
#     katrina       0.99      0.94      0.96        87
#      others       0.95      0.99      0.97        96
#
# avg / total       0.97      0.97      0.97       183
#
# [[82  5]
#  [ 1 95]]
